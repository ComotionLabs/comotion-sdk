# %%
import requests
import jwt
from comotion.dash import DashConfig, Query, Load
from comotion.auth import Auth
# Out:
# Optional dependency 'cx_Oracle' is not installed; Oracle-related features are unavailable.

# %%
org_name = 'cg'
entity_type = Auth.APPLICATION
application_client_id = "CG_EXTERNAL_QUERY_DEFAULT_0"
application_client_secret = "EUwUM3xLocbKAvmJI7WlVL6USc9LQASr"
auth = Auth(orgname=org_name, entity_type=entity_type, application_client_id=application_client_id, application_client_secret=application_client_secret)
config = DashConfig(auth = auth)

# Get the access token and then decode it
access_token = auth.get_access_token()
access_token_decoded = jwt.decode(access_token, options={"verify_signature": False})
print(access_token_decoded)
# Out:
# {'exp': 1767973717, 'iat': 1767973417, 'jti': '06d308ba-8260-481b-bcb6-e002f0a928d7', 'iss': 'https://auth.comotion.us/auth/realms/cg', 'aud': ['cg_client', 'dash_api'], 'sub': 'b52604c5-e4c7-4448-ba11-5469e4c34a44', 'typ': 'Bearer', 'azp': 'CG_EXTERNAL_QUERY_DEFAULT_0', 'acr': '1', 'resource_access': {'cg_client': {'roles': ['APIUser']}, 'dash_api': {'roles': ['AllServiceClientAnalyst', 'query_runner']}}, 'scope': 'profile email query:read service_client query:write', 'email_verified': False, 'clientId': 'CG_EXTERNAL_QUERY_DEFAULT_0', 'clientHost': '41.193.224.48', 'preferred_username': 'service-account-cg_external_query_default_0', 'service_client_id': ['0'], 'clientAddress': '41.193.224.48'}

# %%
query = Query(config= config, query_text = """select * from cg_insights.api_test""")

result =query.wait_to_complete()
# Out:
# state='SUCCEEDED' state_change_reason=None submission_date_time='01-09-2026 15:46:29' completion_date_time='01-09-2026 15:46:30'
# SUCCEEDED
# query='select * from cg_insights.api_test' query_id='77c8cdad-8839-42ca-8af8-d65697d8f2ee' statement_type='DML' status=QueryStatus(state='SUCCEEDED', state_change_reason=None, submission_date_time='01-09-2026 15:46:29', completion_date_time='01-09-2026 15:46:30')
